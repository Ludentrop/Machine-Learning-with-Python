# %% [markdown]
# Дан словарь, и требуется его конвертировать в матрицу признаков.

# %%
import pandas as pd
from sklearn.feature_extraction import DictVectorizer

# %%
data_dict = [{"красный": 2, "синий": 4},
             {"красный": 4, "синий": 3},
             {"красный": 1, "желтый": 2},
             {"красный": 2, "желтый": 2}]

# Dict vectorizer creating
dictvectorizer = DictVectorizer(sparse=False)

# Convert the dict to feature matrix
features = dictvectorizer.fit_transform(data_dict)

features
# Out:
# array([[0., 2., 4.],
#        [0., 4., 3.],
#        [2., 1., 0.],
#        [2., 2., 0.]])

# %%
feature_names = dictvectorizer.get_feature_names_out()

feature_names
# Out:
# array(['желтый', 'красный', 'синий'], dtype=object)

# %%
pd.DataFrame(features, columns=feature_names)
# Out:
#    желтый  красный  синий
# 0     0.0      2.0    4.0
# 1     0.0      4.0    3.0
# 2     2.0      1.0    0.0
# 3     2.0      2.0    0.0
