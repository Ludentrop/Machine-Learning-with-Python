# %%
import numpy as np
import pandas as pd


features = np.array([
    [1.1, 11.1],
    [2.2, 22.2],
    [3.3, 33.3],
    [4.4, 44.4],
    [np.nan, 55]
])

# %%
features[~np.isnan(features).any(axis=1)]
# Out:
# array([[ 1.1, 11.1],
#        [ 2.2, 22.2],
#        [ 3.3, 33.3],
#        [ 4.4, 44.4]])

# %%
data = pd.DataFrame(features, columns=['feature_1', 'feature_2'])

data.dropna()
# Out:
#    feature_1  feature_2
# 0        1.1       11.1
# 1        2.2       22.2
# 2        3.3       33.3
# 3        4.4       44.4
