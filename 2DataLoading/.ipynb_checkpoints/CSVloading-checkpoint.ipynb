# %%
import pandas as pd


# url = 'https://vincentarelbundock.github.io/Rdatasets/csv/openintro/russian_influence_on_us_election_2016.csv'
# url = 'https://tinyurl.com/simulated-excel'
# data = pd.read_csv(url, encoding='unicode_escape')
# print(data.head(2))

url = 'https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/titanic.csv'

data = pd.read_csv(url)

(data.describe())

print(data.iloc[4])

# Set index
data = data.set_index(data['Name'])

print(data.loc['Allison, Master Hudson Trevor'])
